# %% [markdown]
# # Tumor Evolution Modeling
#
# This notebook demonstrates training and evaluation of models for predicting tumor evolution timelines.

# %%
import sys
import os
sys.path.append('../')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
from src.features import FeatureExtractor, create_target_labels
from src.models import TumorEvolutionPredictor
from src.visualization import plot_feature_importance, plot_prediction_timeline
from sklearn.model_selection import train_test_split
